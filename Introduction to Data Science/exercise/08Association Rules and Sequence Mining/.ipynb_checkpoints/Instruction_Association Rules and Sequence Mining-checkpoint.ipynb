# %% [markdown]
# # Association Rules
#
# #### In this section, we will learn about how to use assocition rules in python and how to filter data based on different metrics of association rules.
#
#
# Following libraries are used for association rules:
# - pandas
# - numpy
# - matplotlib
# - mlxtend

# %%
# Import necessary modules

import numpy as np
import pandas as pd
import csv
from matplotlib import pyplot as plt

# Import Apriori module and TransactionEncoder module and association module from mlxtend

from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import association_rules as arule

# %% [markdown]
# ### Read data from repair.csv
#
# We use repair.csv file as a data set for finding frequent item sets. Apriori algorithm is used for finding frequent itemsets.

# %%
# Read file 'repair.csv' and change the data format for Apriori algorithm

data_set = []

with open("repair.csv") as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        data_set.append(row)

# %%
# learn to use TransactionEncoder module to convert an array to DataFrame for Apriori algorithm in mlxtend

te = TransactionEncoder()
te_ary = te.fit(data_set).transform(data_set)
data = pd.DataFrame(te_ary, columns = te.columns_)
data.tail(5)
# learn to use Apriori algorithm from mlxtend

frequent_itemsets = apriori(data, min_support = 0.4, use_colnames = True)

# %% [markdown]
# ### Filtering data based on metrics of Association rules
# In python you can filter frequent itemsets based on different metrics such as support, confidence and lift.

# %%
# learn to use association rule algorithm from mlxtend and filter data based on one metric.

rules_association =arule(frequent_itemsets, metric = 'lift', min_threshold = 0.8)
rules_association
# Out:
#             antecedents                                        consequents  \
# 0      (Analyze Defect)                                   (Archive Repair)
# 1      (Archive Repair)                                   (Analyze Defect)
# 2      (Analyze Defect)                                      (Inform User)
# 3         (Inform User)                                   (Analyze Defect)
# 4      (Analyze Defect)                                         (Register)
# ..                  ...                                                ...
# 727          (Register)  (Inform User, Repair (Complex), Analyze Defect...
# 728  (Repair (Complex))  (Inform User, Register, Analyze Defect, Test R...
# 729    (Analyze Defect)  (Test Repair, Register, Repair (Complex), Info...
# 730       (Inform User)  (Register, Repair (Complex), Analyze Defect, T...
# 731    (Archive Repair)  (Inform User, Register, Repair (Complex), Anal...
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              1.000000            0.905797  0.905797    0.905797  1.000000
# 1              0.905797            1.000000  0.905797    1.000000  1.000000
# 2              1.000000            0.998188  0.998188    0.998188  1.000000
# 3              0.998188            1.000000  0.998188    1.000000  1.000000
# 4              1.000000            1.000000  1.000000    1.000000  1.000000
# ..                  ...                 ...       ...         ...       ...
# 727            1.000000            0.550725  0.550725    0.550725  1.000000
# 728            0.596920            0.905797  0.550725    0.922610  1.018561
# 729            1.000000            0.550725  0.550725    0.550725  1.000000
# 730            0.998188            0.550725  0.550725    0.551724  1.001815
# 731            0.905797            0.595109  0.550725    0.608000  1.021662
#
#      leverage  conviction
# 0    0.000000    1.000000
# 1    0.000000         inf
# 2    0.000000    1.000000
# 3    0.000000         inf
# 4    0.000000         inf
# ..        ...         ...
# 727  0.000000    1.000000
# 728  0.010036    1.217249
# 729  0.000000    1.000000
# 730  0.000998    1.002230
# 731  0.011677    1.032886
#
# [732 rows x 9 columns]

# %% [markdown]
# #### Question:Change the metric to lift and support. Inevestigate the effect of that on the table.

# %% [markdown]
# ### Finding qualified frequent itemsets using association rules
# You can use association rules for finding qualified itemsets for different datasets.

# %% [markdown]
# #### Question:  Find frequent item sets with minimum support of 0.4. Store them in frequent_itemsets variable.

# %%
#Answer
frequent_itemsets = apriori(data, min_support = 0.4, use_colnames = True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   1.000000                                   (Analyze Defect)
# 1   0.905797                                   (Archive Repair)
# 2   0.998188                                      (Inform User)
# 3   1.000000                                         (Register)
# 4   0.596920                                 (Repair (Complex))
# ..       ...                                                ...
# 74  0.550725  (Register, Repair (Complex), Analyze Defect, T...
# 75  0.595109  (Inform User, Register, Repair (Complex), Anal...
# 76  0.438406  (Inform User, Register, Analyze Defect, Repair...
# 77  0.550725  (Inform User, Register, Repair (Complex), Test...
# 78  0.550725  (Test Repair, Register, Repair (Complex), Anal...
#
# [79 rows x 2 columns]

# %% [markdown]
# ### Filtering itemsets based on length and metrics of assosciation rules
# In this section, you will learn how to filter frequent item sets based on length of them.

# %%
# Add another column named 'length' in 'frequent_itemsets' which indicates the number of items in each frequent itemset.

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

# Filter out the frequent itemsets which have a length longer than 2 and a support bigger than 0.3. 

# Store these found itemsets in variable 'frequent_itemsets_filtered'.

frequent_itemsets_filtered = frequent_itemsets.loc[(frequent_itemsets['length'] > 2) & (frequent_itemsets['support'] > 0.3)]   
frequent_itemsets_filtered
# Out:
#      support                                           itemsets  length
# 26  0.905797      (Analyze Defect, Inform User, Archive Repair)       3
# 27  0.905797         (Analyze Defect, Register, Archive Repair)       3
# 28  0.550725  (Analyze Defect, Repair (Complex), Archive Rep...       3
# 29  0.905797      (Analyze Defect, Test Repair, Archive Repair)       3
# 30  0.998188            (Analyze Defect, Inform User, Register)       3
# 31  0.595109    (Analyze Defect, Inform User, Repair (Complex))       3
# 32  0.438406     (Repair (Simple), Analyze Defect, Inform User)       3
# 33  0.998188         (Test Repair, Analyze Defect, Inform User)       3
# 34  0.596920       (Analyze Defect, Register, Repair (Complex))       3
# 35  0.438406        (Repair (Simple), Analyze Defect, Register)       3
# 36  0.998188            (Analyze Defect, Test Repair, Register)       3
# 37  0.595109    (Analyze Defect, Test Repair, Repair (Complex))       3
# 38  0.438406     (Repair (Simple), Analyze Defect, Test Repair)       3
# 39  0.905797            (Inform User, Register, Archive Repair)       3
# 40  0.550725    (Inform User, Repair (Complex), Archive Repair)       3
# 41  0.905797         (Test Repair, Inform User, Archive Repair)       3
# 42  0.550725       (Register, Repair (Complex), Archive Repair)       3
# 43  0.905797            (Test Repair, Register, Archive Repair)       3
# 44  0.550725    (Test Repair, Repair (Complex), Archive Repair)       3
# 45  0.595109          (Inform User, Register, Repair (Complex))       3
# 46  0.438406           (Repair (Simple), Inform User, Register)       3
# 47  0.998188               (Test Repair, Inform User, Register)       3
# 48  0.595109       (Test Repair, Inform User, Repair (Complex))       3
# 49  0.438406        (Repair (Simple), Test Repair, Inform User)       3
# 50  0.595109          (Test Repair, Register, Repair (Complex))       3
# 51  0.438406           (Repair (Simple), Test Repair, Register)       3
# 52  0.905797  (Analyze Defect, Inform User, Register, Archiv...       4
# 53  0.550725  (Analyze Defect, Inform User, Repair (Complex)...       4
# 54  0.905797  (Test Repair, Analyze Defect, Inform User, Arc...       4
# 55  0.550725  (Analyze Defect, Register, Repair (Complex), A...       4
# 56  0.905797  (Analyze Defect, Test Repair, Register, Archiv...       4
# 57  0.550725  (Analyze Defect, Test Repair, Repair (Complex)...       4
# 58  0.595109  (Analyze Defect, Inform User, Register, Repair...       4
# 59  0.438406  (Repair (Simple), Analyze Defect, Inform User,...       4
# 60  0.998188  (Test Repair, Analyze Defect, Inform User, Reg...       4
# 61  0.595109  (Test Repair, Analyze Defect, Inform User, Rep...       4
# 62  0.438406  (Repair (Simple), Test Repair, Analyze Defect,...       4
# 63  0.595109  (Analyze Defect, Test Repair, Register, Repair...       4
# 64  0.438406  (Repair (Simple), Analyze Defect, Test Repair,...       4
# 65  0.550725  (Inform User, Register, Repair (Complex), Arch...       4
# 66  0.905797  (Test Repair, Inform User, Register, Archive R...       4
# 67  0.550725  (Test Repair, Inform User, Repair (Complex), A...       4
# 68  0.550725  (Test Repair, Register, Repair (Complex), Arch...       4
# 69  0.595109  (Test Repair, Inform User, Register, Repair (C...       4
# 70  0.438406  (Repair (Simple), Test Repair, Inform User, Re...       4
# 71  0.550725  (Register, Repair (Complex), Analyze Defect, I...       5
# 72  0.905797  (Inform User, Register, Analyze Defect, Test R...       5
# 73  0.550725  (Inform User, Repair (Complex), Analyze Defect...       5
# 74  0.550725  (Register, Repair (Complex), Analyze Defect, T...       5
# 75  0.595109  (Inform User, Register, Repair (Complex), Anal...       5
# 76  0.438406  (Inform User, Register, Analyze Defect, Repair...       5
# 77  0.550725  (Inform User, Register, Repair (Complex), Test...       5
# 78  0.550725  (Test Repair, Register, Repair (Complex), Anal...       6

# %% [markdown]
# ### Demonstrating selective metrics of association rules in one table
#  In this section, you will learn how to show selective metrics of association rules in one table.

# %%
# Mine association rules from the discovered frequent itemsets stored in variable 'frequent_itemsets', set minimum confidence to 0.5.

# Store the discovered rules in variable 'rules_association'.

rules_association =arule(frequent_itemsets, metric = 'confidence', min_threshold = 0.5)

# Filter out the rules with lift larger than 1 and support larger than 0.4, store the discovered rules in variable 'filtered_rules'.

filtered_rules = rules_association.loc[(rules_association['lift'] > 1) & (rules_association['support'] > 0.4)]     

# Show the columns 'antecedents', 'consequents', 'support', 'confidence' and 'lift' of variable 'filtered_rules' 

filtered_rules[['support', 'confidence', 'lift']]
# Out:
#       support  confidence      lift
# 11   0.905797    0.907441  1.001815
# 12   0.905797    1.000000  1.001815
# 15   0.550725    0.922610  1.018561
# 16   0.550725    0.608000  1.018561
# 17   0.905797    0.907441  1.001815
# ..        ...         ...       ...
# 660  0.550725    0.608000  1.021662
# 661  0.550725    0.551724  1.001815
# 663  0.550725    0.922610  1.018561
# 665  0.550725    0.551724  1.001815
# 666  0.550725    0.608000  1.021662
#
# [441 rows x 3 columns]
